# %% [markdown]
# <a href="https://colab.research.google.com/github/enps2015/etl_exemplo01/blob/main/etl01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import auth
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# %%
# Carregar o dataset 'tips' do Seaborn
data = sns.load_dataset("tips")

data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Calcular a porcentagem da gorjeta em relação ao total da conta
data['tip_porcentage'] = (data['tip'] / data['total_bill']) * 100

data
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_porcentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.680765
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]

# %%
# Salvar o DataFrame em um arquivo CSV
data.to_csv('tips_data.csv', index=False, sep=';', decimal='.')

# %%
# Autenticar o usuário no Google Colab
auth.authenticate_user()

# Construir o serviço do Google Drive
drive_service = build('drive', 'v3')

# Definir metadados do arquivo
file_metadata = {
    'name': 'tips_data.csv',
    'mimeType': 'application/vnd.google-apps.spreadsheet'
}

# Criar o objeto de mídia para upload
media = MediaFileUpload('tips_data.csv', mimetype='text/csv')

# Fazer o upload do arquivo para o Google Drive
uploaded_file = drive_service.files().create(
    body=file_metadata,
    media_body=media,
    fields='id'
).execute()

# %%
# Obter o ID do arquivo enviado
file_id = uploaded_file.get('id')

# Exibir o link para acessar o arquivo no Google Sheets
print(f"\nArquivo enviado para o Google Sheets! Acesse em: https://docs.google.com/spreadsheets/d/{file_id}")
# Out:
# Arquivo enviado para o Google Sheets! Acesse em: https://docs.google.com/spreadsheets/d/1mBetnPBIhFk0Jgl4mI7dFH0Y2O3izEpk9Lon-Lz_izM
